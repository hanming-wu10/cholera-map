# %% [markdown]
# ### Project Files
# - **snow.ipynb** — main analysis and design rationale
# - **cholera_interactive.html** — final interactive visualization (open in browser)
# - **data/** — source datasets (Snow’s data)

# %%
import folium
from folium.plugins import HeatMap, MarkerCluster, MiniMap, Fullscreen
import pandas as pd

# %%
# --- Load and prepare data ---
deaths = pd.read_csv("data/Deaths.tsv", sep="\t")
pumps = pd.read_csv("data/Pumps.tsv", sep="\t")

deaths.columns = deaths.columns.str.lower()
pumps.columns = pumps.columns.str.lower()

# Convert Snow’s original (x, y) map coordinates to rough latitude/longitude
def to_latlon(x, y):
    lon = -0.137 + (x - deaths['x'].mean()) * 0.00003
    lat = 51.513 + (y - deaths['y'].mean()) * 0.00003
    return lat, lon

deaths[['lat', 'lon']] = deaths.apply(lambda r: to_latlon(r['x'], r['y']), axis=1, result_type='expand')
pumps[['lat', 'lon']] = pumps.apply(lambda r: to_latlon(r['x'], r['y']), axis=1, result_type='expand')

# --- Create map ---
m = folium.Map(location=[51.513, -0.137], zoom_start=16, tiles='CartoDB positron')

# --- Create feature layers ---
pump_layer = folium.FeatureGroup(name="Water Pumps")
heat_layer = folium.FeatureGroup(name="Cholera Deaths (Heatmap)")
cluster_layer = folium.FeatureGroup(name="Individual Deaths")

# Add pumps
for i, row in pumps.iterrows():
    folium.Marker(
        [row['lat'], row['lon']],
        icon=folium.Icon(color='blue', icon='tint', prefix='fa'),
        popup=f"<b>Pump {i+1}</b><br>Possible source of infection"
    ).add_to(pump_layer)

# Add heatmap
HeatMap(deaths[['lat', 'lon']], radius=8, blur=12, min_opacity=0.5).add_to(heat_layer)

# Optional: add individual death markers
marker_cluster = MarkerCluster().add_to(cluster_layer)
for _, row in deaths.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=3,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(marker_cluster)

# --- Add layers to map ---
pump_layer.add_to(m)
heat_layer.add_to(m)
cluster_layer.add_to(m)

# --- Add interactive plugins ---
MiniMap(toggle_display=True).add_to(m)
Fullscreen().add_to(m)
folium.LayerControl(collapsed=False).add_to(m)

# --- Add title ---
title_html = '''
     <h3 align="center" style="font-size:20px">
     <b>John Snow's 1854 Cholera Map (Interactive Reimagining)</b></h3>
     <p align="center" style="font-size:14px">
     Explore the spatial distribution of cholera deaths and pump locations around Broad Street, Soho.
     </p>
     '''
m.get_root().html.add_child(folium.Element(title_html))

# --- Display or save ---
m.save("cholera_interactive.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95109d94716889acd96db2b447006489 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;
#      &lt;b&gt;John Snow&#x27;s 1854 Cholera Map (Interactive Reimagining)&lt;/b&gt;&lt;/h3&gt;
#      &lt;p align=&quot;center&quot; style=&quot;font-size:14px&quot;&gt;
#      Explore the spatial distribution of cholera deaths and pump locations around Broad Street, Soho.
#      &lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95109d94716889acd96db2b447006489&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95109d94716889acd96db2b447006489 = L.map(
#                 &quot;map_95109d94716889acd96db2b447006489&quot;,
#                 {
#                     center: [51.513, -0.137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63674f53f69cf869c472f2570b2af184 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63674f53f69cf869c472f2570b2af184.addTo(map_95109d94716889acd96db2b447006489);
#
#
#             var feature_group_0176ebecc754cd4e4df4241644c57b17 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e2f905c509ded0541ebc043e759b5595 = L.marker(
#                 [51.513186088235294, -0.13712994982698962],
#                 {
# }
#             ).addTo(feature_group_0176ebecc754cd4e4df4241644c57b17);
#
#
#             var icon_e4b8e8a3b3981ff6e08955588558973b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4b92818aed29d1de0f17e02e446218ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd5c6d237dcb367bd5f42c02c4fe2ca9 = $(`&lt;div id=&quot;html_bd5c6d237dcb367bd5f42c02c4fe2ca9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Pump 1&lt;/b&gt;&lt;br&gt;Possible source of infection&lt;/div&gt;`)[0];
#                 popup_4b92818aed29d1de0f17e02e446218ea.setContent(html_bd5c6d237dcb367bd5f42c02c4fe2ca9);
#
#
#
#         marker_e2f905c509ded0541ebc043e759b5595.bindPopup(popup_4b92818aed29d1de0f17e02e446218ea)
#         ;
#
#
#
#
#                 marker_e2f905c509ded0541ebc043e759b5595.setIcon(icon_e4b8e8a3b3981ff6e08955588558973b);
#
#
#             var marker_39a53243c596cccc621c5cd010fab1fa = L.marker(
#                 [51.51320408823529, -0.13706094982698963],
#                 {
# }
#             ).addTo(feature_group_0176ebecc754cd4e4df4241644c57b17);
#
#
#             var icon_ce9b21b3148d3c10fa0995f0ad792635 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6fcb0bd90f1f8d7dd8b405fc47ed823f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_036d69199fef6cddedfa917dadf19bc1 = $(`&lt;div id=&quot;htm

# %%
# Load your data (TSV)
deaths = pd.read_csv("data/Deaths.tsv", sep="\t")
pumps = pd.read_csv("data/Pumps.tsv", sep="\t")

# Create the base map
m = folium.Map(location=[51.513, -0.137], zoom_start=17, tiles="CartoDB positron")

# Layer groups
heat_layer = folium.FeatureGroup(name="Cholera Death Heatmap")
pump_layer = folium.FeatureGroup(name="Water Pumps")
cluster_layer = folium.FeatureGroup(name="Death Cluster")

# 🧭 Add pumps
for i, row in pumps.iterrows():
    folium.Marker(
        [row['y'], row['x']],
        icon=folium.Icon(color='blue', icon='tint', prefix='fa'),
        popup=f"<b>Pump {i+1}</b><br>Possible source of infection"
    ).add_to(pump_layer)

# 🔥 Add death heatmap
HeatMap(deaths[['y', 'x']], radius=10, blur=15, min_opacity=0.5).add_to(heat_layer)

# 💀 Optional: clustered individual death markers
marker_cluster = MarkerCluster().add_to(cluster_layer)
for _, row in deaths.iterrows():
    folium.CircleMarker(
        location=[row['y'], row['x']],
        radius=3,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(marker_cluster)

# Add feature layers to map
pump_layer.add_to(m)
heat_layer.add_to(m)
cluster_layer.add_to(m)

# Add useful plugins
MiniMap(toggle_display=True).add_to(m)
Fullscreen().add_to(m)
folium.LayerControl(collapsed=False).add_to(m)

# 🧾 Add title (custom HTML)
title_html = '''
     <h3 align="center" style="font-size:20px">
     <b>John Snow's 1854 Cholera Outbreak Map (Interactive Reimagining)</b></h3>
     <p align="center" style="font-size:14px">Explore the pumps, deaths, and hotspots around Broad Street</p>
     '''
m.get_root().html.add_child(folium.Element(title_html))

# Save or show map
m.save("cholera_interactive.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_733507fe49b9159dc5e18b0d9e65d4f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;
#      &lt;b&gt;John Snow&#x27;s 1854 Cholera Outbreak Map (Interactive Reimagining)&lt;/b&gt;&lt;/h3&gt;
#      &lt;p align=&quot;center&quot; style=&quot;font-size:14px&quot;&gt;Explore the pumps, deaths, and hotspots around Broad Street&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_733507fe49b9159dc5e18b0d9e65d4f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_733507fe49b9159dc5e18b0d9e65d4f9 = L.map(
#                 &quot;map_733507fe49b9159dc5e18b0d9e65d4f9&quot;,
#                 {
#                     center: [51.513, -0.137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d1cdec0821ba7da9f70783d4e18601f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d1cdec0821ba7da9f70783d4e18601f.addTo(map_733507fe49b9159dc5e18b0d9e65d4f9);
#
#
#             var feature_group_75218642ff8e0df20c5d382b2249ceb9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0c329b5b982ca42dd3c860158f2b6f17 = L.marker(
#                 [17.9, 8.7],
#                 {
# }
#             ).addTo(feature_group_75218642ff8e0df20c5d382b2249ceb9);
#
#
#             var icon_b5537bd63933d9b0dde63c4a7e8214f8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_95e9ad9a3866083e9ab0b8124d9c488b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_424e1bb5803213791cf031e881a1ada7 = $(`&lt;div id=&quot;html_424e1bb5803213791cf031e881a1ada7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Pump 1&lt;/b&gt;&lt;br&gt;Possible source of infection&lt;/div&gt;`)[0];
#                 popup_95e9ad9a3866083e9ab0b8124d9c488b.setContent(html_424e1bb5803213791cf031e881a1ada7);
#
#
#
#         marker_0c329b5b982ca42dd3c860158f2b6f17.bindPopup(popup_95e9ad9a3866083e9ab0b8124d9c488b)
#         ;
#
#
#
#
#                 marker_0c329b5b982ca42dd3c860158f2b6f17.setIcon(icon_b5537bd63933d9b0dde63c4a7e8214f8);
#
#
#             var marker_81073dba1b104c1a914ede6e0964b93f = L.marker(
#                 [18.5, 11.0],
#                 {
# }
#             ).addTo(feature_group_75218642ff8e0df20c5d382b2249ceb9);
#
#
#             var icon_55eac06e1148b4a4aca63abf57958222 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dd024e362a44b1505b3e7ee66d375bf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19aadaa6a671c9e8f41278f848fb0900 = $(`&lt;div id=&quot;html_19aadaa6a671c9e8f41278f848fb0900&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&g
